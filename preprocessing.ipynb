# %%
import pandas as pd

# %%
df = pd.read_csv('new_data.csv')

# %%
df
# Out:
#      Unnamed: 0                                                url  \
# 0             0  https://www.goodreads.com/book/show/2767052-th...
# 1             1  https://www.goodreads.com/book/show/2.Harry_Po...
# 2             2  https://www.goodreads.com/book/show/2657.To_Ki...
# 3             3  https://www.goodreads.com/book/show/1885.Pride...
# 4             4  https://www.goodreads.com/book/show/19063.The_...
# ..          ...                                                ...
# 995         995  https://www.goodreads.com/book/show/8685612-th...
# 996         996  https://www.goodreads.com/book/show/7402393-ni...
# 997         997  https://www.goodreads.com/book/show/17343.Till...
# 998         998  https://www.goodreads.com/book/show/32829.Jour...
# 999         999  https://www.goodreads.com/book/show/249.Tropic...
#
#                                                  title           author  \
# 0              The Hunger Games (The Hunger Games, #1)  Suzanne Collins
# ...

# %%
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

# %%
df
# Out:
#                                                    url  \
# 0    https://www.goodreads.com/book/show/2767052-th...
# 1    https://www.goodreads.com/book/show/2.Harry_Po...
# 2    https://www.goodreads.com/book/show/2657.To_Ki...
# 3    https://www.goodreads.com/book/show/1885.Pride...
# 4    https://www.goodreads.com/book/show/19063.The_...
# ..                                                 ...
# 995  https://www.goodreads.com/book/show/8685612-th...
# 996  https://www.goodreads.com/book/show/7402393-ni...
# 997  https://www.goodreads.com/book/show/17343.Till...
# 998  https://www.goodreads.com/book/show/32829.Jour...
# 999  https://www.goodreads.com/book/show/249.Tropic...
#
#                                                  title           author  \
# 0              The Hunger Games (The Hunger Games, #1)  Suzanne Collins
# 1    Harry Potter and the Order of the Phoenix (Har...     J.K. Rowling
# 2                                To Kill a Mockingbird       Harper Lee
# ...

# %%
df.to_csv('newdata.csv')
df.to_csv('C:/Users/busay/OneDrive/Documents/GitHub/Streamlit_weekend/newdata.csv')

# %%
data = pd.read_csv('newdata.csv')
data
# Out:
#      Unnamed: 0                                                url  \
# 0             0  https://www.goodreads.com/book/show/2767052-th...
# 1             1  https://www.goodreads.com/book/show/2.Harry_Po...
# 2             2  https://www.goodreads.com/book/show/2657.To_Ki...
# 3             3  https://www.goodreads.com/book/show/1885.Pride...
# 4             4  https://www.goodreads.com/book/show/19063.The_...
# ..          ...                                                ...
# 995         995  https://www.goodreads.com/book/show/8685612-th...
# 996         996  https://www.goodreads.com/book/show/7402393-ni...
# 997         997  https://www.goodreads.com/book/show/17343.Till...
# 998         998  https://www.goodreads.com/book/show/32829.Jour...
# 999         999  https://www.goodreads.com/book/show/249.Tropic...
#
#                                                  title           author  \
# 0              The Hunger Games (The Hunger Games, #1)  Suzanne Collins
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   url                    1000 non-null   object
#  1   title                  1000 non-null   object
#  2   author                 1000 non-null   object
#  3   num_ratings            1000 non-null   float64
#  4   avg_rating             1000 non-null   float64
#  5   minmax_norm_ratings    1000 non-null   float64
#  6   mean_norm_ratings      1000 non-null   float64
#  7   num_pages              1000 non-null   float64
#  8   original_publish_year  1000 non-null   int64
#  9   series                 1000 non-null   object
#  10  genres                 1000 non-null   object
#  11  awards                 1000 non-null   object
#  12  places                 1000 non-null   object
# dtypes: float64(5), int64(1), object(7)
# memory usage: 101.7+ KB
